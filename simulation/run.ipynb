# %%
# %run -i "simulation.py"
# Out:
# Sizes: [200, 500, 1000, 5000, 10000] and [200, 500, 1000, 2000] for Sheather-Jones
# Number of iterations: 500 and 300 for Sheather-Jones
# -------------------------------------------
# Simulation with estimator fixed_gaussian
# 05-23-20 01:42:00: Simulating with `bw_name` silverman
# 05-23-20 01:42:00: Size 200
# 05-23-20 01:42:02: Size 500
# 05-23-20 01:42:04: Size 1000
# 05-23-20 01:42:06: Size 5000
# 05-23-20 01:42:08: Size 10000
# 05-23-20 01:42:10: Finshed gaussian_1
# 05-23-20 01:42:10: Size 200
# 05-23-20 01:42:13: Size 500
# 05-23-20 01:42:15: Size 1000
# 05-23-20 01:42:17: Size 5000
# 05-23-20 01:42:19: Size 10000
# 05-23-20 01:42:21: Finshed gaussian_2
# 05-23-20 01:42:21: Size 200
# 05-23-20 01:42:27: Size 500
# 05-23-20 01:42:31: Size 1000
# 05-23-20 01:42:34: Size 5000
# 05-23-20 01:42:37: Size 10000
# 05-23-20 01:42:40: Finshed gmixture_1
# 05-23-20 01:42:40: Size 200
# 05-23-20 01:42:42: Size 500
# 05-23-20 01:42:44: Size 1000
# 05-23-20 01:42:47: Size 5000
# ...
